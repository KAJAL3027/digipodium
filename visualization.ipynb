# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(iris,x='sepal_length',bins=20,kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(iris,x='sepal_width',bins=20,kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
fig, ax = plt.subplots(figsize=(5,3))
sns.histplot(iris,x='sepal_width',bins=15,kde=True,ax=ax)
plt.savefig('sepal_width_hist.png',dpi=300)

# %%
sns.histplot(iris,x='petal_length',bins=20,kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(iris,x='petal_width',bins=20,kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.set_palette('rainbow')
fig , ax=plt.subplots(figsize=(20,5),ncols=4)
sns.histplot(iris,x='sepal_width',bins=15,kde=True,ax=ax[0])
sns.histplot(iris,x='petal_width',bins=15,kde=True,ax=ax[1])
sns.histplot(iris,x='sepal_length',bins=15,kde=True,ax=ax[2])
sns.histplot(iris,x='petal_length',bins=15,kde=True,ax=ax[3])
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.set_palette('rainbow')
fig , ax=plt.subplots(figsize=(15,8),ncols=2,nrows=2)
sns.histplot(iris,x='sepal_width',bins=15,kde=True,ax=ax[0,0],color='red')
sns.histplot(iris,x='petal_width',bins=15,kde=True,ax=ax[0,1],color='orange')
sns.histplot(iris,x='sepal_length',bins=15,kde=True,ax=ax[1,0],color='black')
sns.histplot(iris,x='petal_length',bins=15,kde=True,ax=ax[1,1])
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.barplot(data=iris,x='species',y='sepal_length')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(iris,errorbar=None)
# Out:
# <Axes: >

# %%
sns.scatterplot(iris,x='sepal_length',y='sepal_width',hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(iris,x='sepal_length',y='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.jointplot(iris,x='sepal_length',y='sepal_width',hue='species')

# %%
sns.scatterplot(iris,x='petal_length',y='petal_width')

# %%
sns.jointplot(iris,x='petal_length',y='petal_width',hue='species')
