# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
a = cv2.imread("parrot.jpg")
print(a)
# Out:
# None

# %%
plt.imshow(a)

# %%
b = cv2.cvtcolor(a,cv2.COLOR_BGR2GRAY)
plt.imshow(b,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 b = cv2.cvtcolor(a,cv2.COLOR_BGR2GRAY)
#       2 plt.imshow(b,cmap='gray')
#
# AttributeError: module 'cv2' has no attribute 'cvtcolor'

# %%
c=cv2.cvtcolor(a,cv2.COLOR_BGR2RGB)
plt.imshow(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 c=cv2.cvtcolor(a,cv2.COLOR_BGR2RGB)
#       2 plt.imshow(c)
#
# AttributeError: module 'cv2' has no attribute 'cvtcolor'

# %%
#resize by resolution
print(a.shape)
cr = cv2.resize(c,(1600,1500))
plt.imshow(cr)
# Out:
# (1000, 1600, 3)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 #resize by resolution
#       2 print(a.shape)
# ----> 3 cr = cv2.resize(c,(1600,1500))
#       4 plt.imshow(cr)
#
# NameError: name 'c' is not defined

# %%
# resize by scale
cscaled = cv2.resize(c,None,fx=0.5,fy=0.5) # image reduced by 50%
plt.imshow(cscaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # resize by scale
# ----> 2 cscaled = cv2.resize(c,None,fx=0.5,fy=0.5) # image reduced by 50%
#       3 plt.imshow(cscaled)
#
# NameError: name 'c' is not defined

# %%
# apply blur
cblur = cv2.GaussianBlur(c,(19,19),0)
plt.imshow(cblur)

# %%
# apply edge detection
cgray = cv2.cvtcolor(c,cv2.COLOR_RGB2BGR)
cgray = cv2.GaussianBlur(cgray,(5,5),0)
cgray = cv2.Canny,cmap
